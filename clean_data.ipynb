# %%
# imports 
import pandas as pd

# %%
raw_dataset = pd.read_csv("./testdata/Gediplomeerden__onderwijssoort__woonregio_13022024_132550.csv", skiprows=5, sep=";")

raw_dataset.head()
# Out:
#                          Unnamed: 0 Nederland Noord-Nederland (LD)  \
# 0                    Onderwijssoort    aantal               aantal
# 1  Totaal voortgezet onderwijs (vo)    167410                16200
# 2                               Vwo     35610                 2830
# 3                              Havo     45410                 4340
# 4                          Vmbo g/t     47340                 4760
#
#   Oost-Nederland (LD) West-Nederland (LD) Zuid-Nederland (LD)  \
# 0              aantal              aantal              aantal
# 1               38620               78840               33410
# 2                6970               18980                6760
# 3               10450               21400                9140
# 4               11140               21490                9840
#
#   Niet in te delen (LD) Groningen (PV) Fryslân (PV) Drenthe (PV)  ...  \
# 0                aantal         aantal       aantal       aantal  ...
# ...

# %%
with_renamed_column = raw_dataset.rename(columns={"Unnamed: 0":"Onderwijssoort"})
with_renamed_column.head()
# Out:
#                      Onderwijssoort Nederland Noord-Nederland (LD)  \
# 0                    Onderwijssoort    aantal               aantal
# 1  Totaal voortgezet onderwijs (vo)    167410                16200
# 2                               Vwo     35610                 2830
# 3                              Havo     45410                 4340
# 4                          Vmbo g/t     47340                 4760
#
#   Oost-Nederland (LD) West-Nederland (LD) Zuid-Nederland (LD)  \
# 0              aantal              aantal              aantal
# 1               38620               78840               33410
# 2                6970               18980                6760
# 3               10450               21400                9140
# 4               11140               21490                9840
#
#   Niet in te delen (LD) Groningen (PV) Fryslân (PV) Drenthe (PV)  ...  \
# 0                aantal         aantal       aantal       aantal  ...
# ...

# %%
deleted_first_row_data = with_renamed_column.iloc[1:]
deleted_first_row_data.head()
# Out:
#                      Onderwijssoort Nederland Noord-Nederland (LD)  \
# 1  Totaal voortgezet onderwijs (vo)    167410                16200
# 2                               Vwo     35610                 2830
# 3                              Havo     45410                 4340
# 4                          Vmbo g/t     47340                 4760
# 5                            Vmbo-k     24870                 2840
#
#   Oost-Nederland (LD) West-Nederland (LD) Zuid-Nederland (LD)  \
# 1               38620               78840               33410
# 2                6970               18980                6760
# 3               10450               21400                9140
# 4               11140               21490                9840
# 5                6590               10500                4890
#
#   Niet in te delen (LD) Groningen (PV) Fryslân (PV) Drenthe (PV)  ...  \
# 1                   340           4700         6490         5020  ...
# ...

# %%
deleted_first_row_data
# Out:
#                       Onderwijssoort Nederland Noord-Nederland (LD)  \
# 1   Totaal voortgezet onderwijs (vo)    167410                16200
# 2                                Vwo     35610                 2830
# 3                               Havo     45410                 4340
# 4                           Vmbo g/t     47340                 4760
# 5                             Vmbo-k     24870                 2840
# 6                             Vmbo-b     14180                 1430
# 7                        Totaal vavo      5250                  460
# 8                           Vavo vwo      1560                  160
# 9                          Vavo havo      3050                  270
# 10                       Vavo vmbo-t       640                   40
# 11       Totaal mbo (incl. extranei)    152040                17960
# 12   Entreeopleiding (incl.extranei)     11500                 1210
# 13     Niveau 2 (inclusief extranei)     33950                 3770
# ...

# %%
last_row_deleted = deleted_first_row_data.iloc[:-1]
last_row_deleted
# Out:
#                       Onderwijssoort Nederland Noord-Nederland (LD)  \
# 1   Totaal voortgezet onderwijs (vo)    167410                16200
# 2                                Vwo     35610                 2830
# 3                               Havo     45410                 4340
# 4                           Vmbo g/t     47340                 4760
# 5                             Vmbo-k     24870                 2840
# 6                             Vmbo-b     14180                 1430
# 7                        Totaal vavo      5250                  460
# 8                           Vavo vwo      1560                  160
# 9                          Vavo havo      3050                  270
# 10                       Vavo vmbo-t       640                   40
# 11       Totaal mbo (incl. extranei)    152040                17960
# 12   Entreeopleiding (incl.extranei)     11500                 1210
# 13     Niveau 2 (inclusief extranei)     33950                 3770
# ...

# %%
df = last_row_deleted
df.head()
# Out:
#                      Onderwijssoort Nederland Noord-Nederland (LD)  \
# 1  Totaal voortgezet onderwijs (vo)    167410                16200
# 2                               Vwo     35610                 2830
# 3                              Havo     45410                 4340
# 4                          Vmbo g/t     47340                 4760
# 5                            Vmbo-k     24870                 2840
#
#   Oost-Nederland (LD) West-Nederland (LD) Zuid-Nederland (LD)  \
# 1               38620               78840               33410
# 2                6970               18980                6760
# 3               10450               21400                9140
# 4               11140               21490                9840
# 5                6590               10500                4890
#
#   Niet in te delen (LD) Groningen (PV) Fryslân (PV) Drenthe (PV)  ...  \
# 1                   340           4700         6490         5020  ...
# ...

# %%
df.to_pickle("./saved_clean_data.pkl")

# %%
unpickled_df = pd.read_pickle("./saved_clean_data.pkl")
unpickled_df.head()
# Out:
#                      Onderwijssoort Nederland Noord-Nederland (LD)  \
# 1  Totaal voortgezet onderwijs (vo)    167410                16200
# 2                               Vwo     35610                 2830
# 3                              Havo     45410                 4340
# 4                          Vmbo g/t     47340                 4760
# 5                            Vmbo-k     24870                 2840
#
#   Oost-Nederland (LD) West-Nederland (LD) Zuid-Nederland (LD)  \
# 1               38620               78840               33410
# 2                6970               18980                6760
# 3               10450               21400                9140
# 4               11140               21490                9840
# 5                6590               10500                4890
#
#   Niet in te delen (LD) Groningen (PV) Fryslân (PV) Drenthe (PV)  ...  \
# 1                   340           4700         6490         5020  ...
# ...
