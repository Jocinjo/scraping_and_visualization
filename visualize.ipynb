# %%
print("hello")
# Out:
# hello

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_pickle("./saved_clean_data.pkl")
df.head()
# Out:
#                      Onderwijssoort Nederland Noord-Nederland (LD)  \
# 1  Totaal voortgezet onderwijs (vo)    167410                16200
# 2                               Vwo     35610                 2830
# 3                              Havo     45410                 4340
# 4                          Vmbo g/t     47340                 4760
# 5                            Vmbo-k     24870                 2840
#
#   Oost-Nederland (LD) West-Nederland (LD) Zuid-Nederland (LD)  \
# 1               38620               78840               33410
# 2                6970               18980                6760
# 3               10450               21400                9140
# 4               11140               21490                9840
# 5                6590               10500                4890
#
#   Niet in te delen (LD) Groningen (PV) Fryslân (PV) Drenthe (PV)  ...  \
# 1                   340           4700         6490         5020  ...
# ...

# %%
df
# Out:
#                       Onderwijssoort Nederland Noord-Nederland (LD)  \
# 1   Totaal voortgezet onderwijs (vo)    167410                16200
# 2                                Vwo     35610                 2830
# 3                               Havo     45410                 4340
# 4                           Vmbo g/t     47340                 4760
# 5                             Vmbo-k     24870                 2840
# 6                             Vmbo-b     14180                 1430
# 7                        Totaal vavo      5250                  460
# 8                           Vavo vwo      1560                  160
# 9                          Vavo havo      3050                  270
# 10                       Vavo vmbo-t       640                   40
# 11       Totaal mbo (incl. extranei)    152040                17960
# 12   Entreeopleiding (incl.extranei)     11500                 1210
# 13     Niveau 2 (inclusief extranei)     33950                 3770
# ...

# %%
# sns.scatterplot(data=tips, x="total_bill", y="tip")
sns.displot(data=df, x="Nederland")
# sns.displot(data=penguins, x="flipper_length_mm")
# Out:
# /home/josie/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df.plot(kind='scatter', x='Onderwijssoort', y='Nederland')
# Out:
# <Axes: xlabel='Onderwijssoort', ylabel='Nederland'>

# %%
df.columns
# Out:
# Index(['Onderwijssoort', 'Nederland', 'Noord-Nederland (LD)',
#        'Oost-Nederland (LD)', 'West-Nederland (LD)', 'Zuid-Nederland (LD)',
#        'Niet in te delen (LD)', 'Groningen (PV)', 'Fryslân (PV)',
#        'Drenthe (PV)', 'Overijssel (PV)', 'Flevoland (PV)', 'Gelderland (PV)',
#        'Utrecht (PV)', 'Noord-Holland (PV)', 'Zuid-Holland (PV)',
#        'Zeeland (PV)', 'Noord-Brabant (PV)', 'Limburg (PV)',
#        'Niet in te delen (PV)', 'Vier grootste gemeenten',
#        'Meer dan 100 000 inwoners (exclusief G4)',
#        'Minder dan 100 000 inwoners', 'Niet in te delen'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 1 to 20
# Data columns (total 24 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Onderwijssoort                            20 non-null     object
#  1   Nederland                                 20 non-null     object
#  2   Noord-Nederland (LD)                      20 non-null     object
#  3   Oost-Nederland (LD)                       20 non-null     object
#  4   West-Nederland (LD)                       20 non-null     object
#  5   Zuid-Nederland (LD)                       20 non-null     object
#  6   Niet in te delen (LD)                     20 non-null     object
#  7   Groningen (PV)                            20 non-null     object
#  8   Fryslân (PV)                              20 non-null     object
#  9   Drenthe (PV)                              20 non-null     object
# ...

# %%
df.set_index(['Onderwijssoort'], inplace=True)

df = df.astype('int64')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Totaal voortgezet onderwijs (vo) to Wo-master
# Data columns (total 23 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Nederland                                 20 non-null     int64
#  1   Noord-Nederland (LD)                      20 non-null     int64
#  2   Oost-Nederland (LD)                       20 non-null     int64
#  3   West-Nederland (LD)                       20 non-null     int64
#  4   Zuid-Nederland (LD)                       20 non-null     int64
#  5   Niet in te delen (LD)                     20 non-null     int64
#  6   Groningen (PV)                            20 non-null     int64
#  7   Fryslân (PV)                              20 non-null     int64
#  8   Drenthe (PV)                              20 non-null     int64
#  9   Overijssel (PV)                           20 non-null     int64
# ...

# %%
df
# Out:
#                                   Nederland  Noord-Nederland (LD)  \
# Onderwijssoort
# Totaal voortgezet onderwijs (vo)     167410                 16200
# Vwo                                   35610                  2830
# Havo                                  45410                  4340
# Vmbo g/t                              47340                  4760
# Vmbo-k                                24870                  2840
# Vmbo-b                                14180                  1430
# Totaal vavo                            5250                   460
# Vavo vwo                               1560                   160
# Vavo havo                              3050                   270
# Vavo vmbo-t                             640                    40
# Totaal mbo (incl. extranei)          152040                 17960
# Entreeopleiding (incl.extranei)       11500                  1210
# Niveau 2 (inclusief extranei)         33950                  3770
# ...

# %%
# df.set_index(['Onderwijssoort'], inplace=True)
# df.head()

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(
    df, 
    alpha=0.2, 
    figsize=(8, 8), 
    diagonal='kde',
)
# Out:
# array([[<Axes: xlabel='Nederland', ylabel='Nederland'>,
#         <Axes: xlabel='Noord-Nederland (LD)', ylabel='Nederland'>,
#         <Axes: xlabel='Oost-Nederland (LD)', ylabel='Nederland'>,
#         <Axes: xlabel='West-Nederland (LD)', ylabel='Nederland'>,
#         <Axes: xlabel='Zuid-Nederland (LD)', ylabel='Nederland'>,
#         <Axes: xlabel='Niet in te delen (LD)', ylabel='Nederland'>,
#         <Axes: xlabel='Groningen (PV)', ylabel='Nederland'>,
#         <Axes: xlabel='Fryslân (PV)', ylabel='Nederland'>,
#         <Axes: xlabel='Drenthe (PV)', ylabel='Nederland'>,
#         <Axes: xlabel='Overijssel (PV)', ylabel='Nederland'>,
#         <Axes: xlabel='Flevoland (PV)', ylabel='Nederland'>,
#         <Axes: xlabel='Gelderland (PV)', ylabel='Nederland'>,
#         <Axes: xlabel='Utrecht (PV)', ylabel='Nederland'>,
#         <Axes: xlabel='Noord-Holland (PV)', ylabel='Nederland'>,
#         <Axes: xlabel='Zuid-Holland (PV)', ylabel='Nederland'>,
# ...
